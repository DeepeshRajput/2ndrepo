# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Deepesh Rajput**
# <br>Masters in Civil engineering

# %% [markdown]
# *Interested in Data Science as it is the most interesting futurisitic job that is going to be needed in all sectors.As it provide greater insight of how to improve upon past.*

# %% [markdown]
# ### addition of any two positive integer

# %%
2+3
# Out:
# 5

# %% [markdown]
# | rollno. | Name|
# | ----| ----|
# | 20156   | Deepesh rajput |
# | 20158 | Saket singh |

# %% [markdown]
# 1. Deepesh Rajput
# 2. Divya Rajput
# 3. Rachna Rajput

# %% [markdown]
# <img src="url/filename.gif" alt="Alt text" title="Title text" />
